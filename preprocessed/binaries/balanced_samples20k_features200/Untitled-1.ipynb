# %%
import pandas as pd

# %%
df2 = pd.read_csv("/home/ufamlas/datasets-main/preprocessed/binaries/balanced/balanced_adroit.csv")
df3 = pd.read_csv("/home/ufamlas/datasets-main/preprocessed/binaries/balanced_undersampling/mh100-balanced.csv")

# %%
df3.shape
df3.head()
# Out:
#    Permission::WAKE_LOCK  Permission::WRITE_EXTERNAL_STORAGE  \
# 0                      1                                   1
# 1                      1                                   1
# 2                      1                                   1
# 3                      1                                   0
# 4                      0                                   0
#
#    Permission::ACCESS_NETWORK_STATE  Permission::WRITE_SETTINGS  \
# 0                                 1                           0
# 1                                 1                           0
# 2                                 1                           0
# 3                                 1                           0
# 4                                 1                           0
#
#    Permission::INTERNET  Intent::AUDIO_BECOMING_NOISY  \
# 0                     1                             0
# 1                     1                             0
# ...

# %%
data = pd.DataFrame(df3)
data.head()
# Out:
#    Permission::WAKE_LOCK  Permission::WRITE_EXTERNAL_STORAGE  \
# 0                      1                                   1
# 1                      1                                   1
# 2                      1                                   1
# 3                      1                                   0
# 4                      0                                   0
#
#    Permission::ACCESS_NETWORK_STATE  Permission::WRITE_SETTINGS  \
# 0                                 1                           0
# 1                                 1                           0
# 2                                 1                           0
# 3                                 1                           0
# 4                                 1                           0
#
#    Permission::INTERNET  Intent::AUDIO_BECOMING_NOISY  \
# 0                     1                             0
# 1                     1                             0
# ...

# %%
data.loc[data["class"] == 1].shape
# Out:
# (5000, 24834)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Columns: 24834 entries, Permission::WAKE_LOCK to class
# dtypes: int64(24834)
# memory usage: 1.9 GB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6836 entries, 0 to 6835
# Columns: 119 entries, android.permission.BIND_WALLPAPER to class
# dtypes: int64(119)
# memory usage: 6.2 MB
